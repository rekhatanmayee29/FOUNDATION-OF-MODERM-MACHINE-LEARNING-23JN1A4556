# %% [markdown]
# <a href="https://colab.research.google.com/github/rekhatanmayee29/FOUNDATION-OF-MODERM-MACHINE-LEARNING-23JN1A4556/blob/main/Module8%20Lab%203%20-%20Applying%20Bayes%20Classifiers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-04-20 14:10:41--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   199MB/s    in 0.3s
#
# 2025-04-20 14:10:42 (199 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 420     1411.1752v1  To cope with the high level of ambiguity faced...    cs
# 22645  1703.06240v1  Bandit methods for black-box optimisation, suc...  stat
# 25787  1511.06704v1  Visual dictionaries are a critical component f...    cs
# 16212  1610.09091v3  We focus on the problem of learning distribute...    cs
# 30897  1801.08360v1  Due to the impressive learning power, deep lea...    cs
# ...             ...                                                ...   ...
# 15045   1302.5645v1  This project is a part of nature language proc...    cs
# 13048   1312.6969v1  Time series are used in many domains including...  stat
# 14817   1107.1753v1  These notes are a continuation of topics cover...    cs
# 2645   1703.05449v2  We consider the problem of provably optimal ex...  stat
# 35239  cs/0203013v1  We consider the two-fold problem of representi...    cs
#
#                                                    title  year  \
# 420    Submodular meets Structured: Finding Diverse S...  2014
# 22645  Multi-fidelity Bayesian Optimisation with Cont...  2017
# 25787  Semantic Diversity versus Visual Diversity in ...  2015
# 16212   Representation Learning Models for Entity Search  2016
# 30897              Dual Asymmetric Deep Hashing Learning  2018
# ...                                                  ...   ...
# 15045  Role of temporal inference in the recognition ...  2013
# 13048  Time series modeling by a regression approach ...  2013
# 14817                   Notes on Electronic Lexicography  2011
# 2645    Minimax Regret Bounds for Reinforcement Learning  2017
# 35239   Representing and Aggregating Conflicting Beliefs  2002
#
#                                                 keywords
# 420    [ambiguity, processing, prediction, candidate,...
# 22645  [optimisation, optimisation, applications, inc...
# 25787  [dictionaries, component, classificationretrie...
# 16212  [distributed, representations, descriptions, r...
# 30897  [impressive, remarkable, performance, supervis...
# ...                                                  ...
# 15045  [processing, recognition, inference, appointed...
# 13048  [including, engineering, economics, bioinforma...
# 14817  [continuation, electronic, dictionaries, compu...
# 2645   [exploration, reinforcement, optimistic, modif...
# 35239  [representing, collective, aggregating, transi...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 420      [ambiguity, processing, prediction, candidate,...
# 22645    [optimisation, optimisation, applications, inc...
# 25787    [dictionaries, component, classificationretrie...
# 16212    [distributed, representations, descriptions, r...
# 30897    [impressive, remarkable, performance, supervis...
#                                ...
# 11064    [regression, components, adversarial, stochast...
# 6631     [introduce, factorisation, integration, combin...
# 25324    [supervised, recognition, semidiscrete, transl...
# 29014    [coherence, tomography, favorable, dermatology...
# 27064    [community, witnessed, continuous, registratio...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8855 words.
# Out of those 4585 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3055ac0d-b603-488d-905a-3b0d34c00add" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3055ac0d-b603-488d-905a-3b0d34c00add")) {                    Plotly.newPlot(                        "3055ac0d-b603-488d-905a-3b0d34c00add",                        [{"x":["exponentially","prediction","significantly","ambiguity","connections","proposals","combinatorial","labelings","solutions","maximization","inference","tradeoffs","candidate","graphical","representations","constructions","appropriately","approximate","diversity","structured","augmentation","processing","potentials","algorithms","specifically","efficient","submodular","functions","constructed","synthetic","increasingly","experiments","available","dimensional","characterise","considerable","expensive","theoretical","experiment","baselines","strategies","optimisation","including","emphmulti","attention","validation","approximations","practical","applications","outperforms","performance","evaluations","properties","iterations","continuous","parameter","dictionary","supervision","representative","importance","collection","descriptors","generating","alleviate","important","classification","obtaining","opportunity","semantics","component","classificationretrieval","straightforward","dictionaries","conclusions","appearances","different","verifying","collections","descriptions","effective","distributed","difference","relationship","celebrities","restaurants","strengths","experimental","representation","outperform","represented","weaknesses","description","remarkable","simultaneously","algorithm","similarity","convergence","categories","alternating","supervised","furthermore","contributes","efficiently","retrieval","substantiate","impressive","introduced","structure","superiority","effectiveness","advantage","minimizing","structures","asymmetric","according","stochastic","asymptotic","optimality","cumulative","providing","numerical","accompanied","literature","asymptotically","comparison","bernoulli","positively","corresponding","acquiring","unrelated","separable","knowledge","marginally","variables","probabilistic","uncoupled","partitioned","respectively","disconnected","independent","relevance","containing","transitive","formulations","recognizing","convolution","extraction","comparing","currently","intricate","frequency","discriminative","recognition","architectures","convincing","additionally","addresses","extremely","posterior","partition","presented","particular","technique","demonstrate","unbalanced","dirichlet","parameters","clustering","automatically","objective","observations","increasing","expression","scenarios","conducted","environments","empirical","exploitative","discounting","distribution","extensive","optimistic","stationary","probability","systematically","approaches","integration","sentiment","framework","convolutional","embedding","embeddings","unlabeled","categorization","competing","resources","designing","reflecting","stabilizing","infrastructures"],"y":[27,204,265,24,60,31,36,3,154,29,209,6,45,64,199,6,13,117,44,100,20,258,17,573,175,428,6,196,57,154,48,595,319,192,3,37,71,146,59,65,89,15,256,0,161,65,30,134,423,283,906,51,215,24,120,116,55,50,48,80,87,45,106,30,362,529,37,13,98,92,1,33,20,29,8,778,4,22,33,242,102,56,70,3,2,18,405,364,98,73,12,80,22,103,833,157,114,70,27,231,164,15,157,108,3,18,108,330,49,197,98,51,125,5,92,111,14,9,4,92,84,6,117,6,128,6,7,104,19,10,12,367,2,128,159,1,8,91,3,130,35,62,5,12,46,36,124,81,44,1,62,108,388,115,4,74,58,44,38,23,190,280,252,544,3,20,270,121,192,153,78,99,47,93,93,84,155,1,2,200,186,5,24,157,18,434,47,38,546,343,112,90,36,31,32,67,44,2,2,6],"type":"bar"},{"x":["exponentially","prediction","significantly","ambigui ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4585,), (4585, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8008333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Joint</span> <span style=''>Matrix</span> <span style=''>Tensor</span> <span style='background-color:rgba(255, 0, 0, 0.3666666666666667);'>Factorization</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.4142581888246628);'>Knowledge</span> <span style=''>Base</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Inference</span> <br/><br/><span style=''>While</span> <span style=''>several</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3666666666666667);'>factorization</span> <span style=''>(MF)</span> <span style=''>and</span> <span style=''>tensor</span> <span style='background-color:rgba(255, 0, 0, 0.3666666666666667);'>factorization</span> <span style=''>(TF)</span> <span style=''>models</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.4142581888246628);'>knowledge</span> <span style=''>base</span> <span style=''>(KB)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>they</span> <span style=''>have</span> <span style=''>rarely</span> <span style=''>been</span> <span style=''>compared</span> <span style=''>across</span> <span style=''>various</span> <span style=''>datasets</span> <span style=''>Is</span> <span style=''>there</span> <span style=''>a</span> <span style=''>single</span> <span style=''>model</span> <span style=''>that</span> <span style=''>performs</span> <span style=''>well</span> <span style=''>across</span> <span style=''>datasets</span> <span style=''>If</span> <span style=''>not</span> <span style=''>what</span> <span style='background-color:rgba(0, 255, 0, 0.5625);'>characteristics</span> <span style=''>of</span> <span style=''>a</span> <span style=''>dataset</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>determine</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>MF</span> <span style=''>and</span> <span style=''>TF</span> <span style=''>models</span> <span style=''>Is</span> <span style=''>there</span> <span style=''>a</span> <span style=''>joint</span> <span style=''>TFMF</span> <span style=''>model</span> <span style=''>that</span> <span style=''>performs</span> <span style=''>robustly</span> <span style=''>on</span> <span style=''>all</span> <span style=''>datasets</span> <span style=''>We</span> <span style=''>perform</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.31448763250883394);'>extensive</span> <span style='background-color:rgba(0, 255, 0, 0.4453781512605042);'>evaluation</span> <span style=''>to</span> <span style=''>compare</span> <span style=''>popular</span> <span style=''>KB</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>models</span> <span style=''>across</span> <span style=''>popular</span> <span style=''>datasets</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.8285714285714286);'>answering</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4757281553398059);'>questions</span> <span style=''>above</span> <span style=''>we</span> <span style=''>remove</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>limitation</span> <span style=''>in</span> <span style=''>the</span> <span style=''>standard</span> <span style='background-color:rgba(0, 255, 0, 0.4453781512605042);'>evaluation</span> <span style=''>protocol</span> <span style=''>for</span> <span style=''>MF</span> <span style=''>models</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0. ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Supervised</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>remark</span> <span style=''>and</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparisons</span> <br/><br/><span style=''>The</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>(or</span> <span style=''>discrimination)</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>data</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>with</span> <span style=''>a</span> <span style=''>special</span> <span style=''>interest</span> <span style=''>on</span> <span style=''>the</span> <span style=''>popular</span> <span style=''>k</span> <span style=''>nearest</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>neighbors</span> <span style=''>(k</span> <span style=''>NN)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>First</span> <span style=''>relying</span> <span style=''>on</span> <span style=''>a</span> <span style=''>recent</span> <span style=''>result</span> <span style=''>by</span> <span style=''>Cerou</span> <span style=''>and</span> <span style=''>Guyader</span> <span style=''>(2006)</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistency</span> <span style=''>of</span> <span style=''>the</span> <span style=''>k</span> <span style=''>NN</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>data</span> <span style=''>whose</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>belongs</span> <span style=''>to</span> <span style=''>a</span> <span style=''>broad</span> <span style=''>family</span> <span style=''>of</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>triangular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>Second</span> <span style=''>on</span> <span style=''>a</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style=''>side</span> <span style=''>we</span> <span style=''>check</span> <span style=''>the</span> <span style=''>behavior</span> <span style=''>of</span> <span style=''>the</span> <span style=''>k</span> <span style=''>NN</span> <span style=''>method</span> <span style=''>when</span> <span style=''>compared</span> <span style=''>with</span> <span style=''>a</span> <span style=''>few</span> <span style=''>other</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>This</span> <span style=''>is</span> <span style=''>carried</span> <span style=''>out</span> <span style=''>through</span> <span style=''>a</span> <span style=''>small</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulation</span> <span style=''>study</span> <span style=''>and</span> <span style=''>the</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>several</span> <span style=''>real</span> <span style='backgro ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Resilience</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Criterion</span> <span style=''>for</span> <span style=''>Learning</span> <span style=''>in</span> <span style=''>the</span> <span style=''>Presence</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Arbitrary</span> <span style=''>Outliers</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resilience</span> <span style=''>which</span> <span style=''>allows</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>a</span> <span style=''>dataset</span> <span style=''>(such</span> <span style=''>as</span> <span style=''>its</span> <span style=''>mean</span> <span style=''>or</span> <span style=''>best</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>approximation)</span> <span style=''>to</span> <span style=''>be</span> <span style=''>robustly</span> <span style=''>computed</span> <span style=''>even</span> <span style=''>in</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>a</span> <span style=''>large</span> <span style=''>fraction</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>additional</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Resilience</span> <span style=''>is</span> <span style=''>a</span> <span style=''>weaker</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>condition</span> <span style=''>than</span> <span style=''>most</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considered</span> <span style=''>so</span> <span style=''>far</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>and</span> <span style=''>yet</span> <span style=''>enables</span> <span style=''>robust</span> <span style='background-color:rgba(255, 0, 0, 0.3005671077504726);'>estimation</span> <span style=''>in</span> <span style=''>a</span> <span style=''>broader</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>settings</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.37142857142857144);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretic</span> <span style=''>results</span> <span style=''>on</span> <span style=''>robust</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>learning</span> <span style=''>robust</span> <span style='background-color:rgba(255, 0, 0, 0.3005671077504726);'>estimation</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.4095744680851064);'>stochastic</span> <span style=''>block</span> <span style=''>models</span> <span style=''>and</span> <span style=''>robust</span> <span style=''>mean</span> <span style='background-color:rgba(255, 0, 0, 0.3005671077504726);'>estimation</span> <span style=''>under</span> <span style=''>bounded</span> <span style=''>kth</span> <span style=''>moments</span> <span style=''>We</span> <span style=''>also</span> <span style=''>provide</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithmic</span> <span style=''>results</span> <span style=''>on</span> <span style=''>robust</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>l ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Classification</span> <span style=''>of</span> <span style=''>Cell</span> <span style=''>Images</span> <span style=''>Using</span> <span style=''>MPEG</span> <span style=''>7</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>influenced</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Descriptors</span> <span style=''>and</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machines</span> <span style=''>in</span> <span style=''>Cell</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Morphology</span> <br/><br/><span style=''>Counting</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifying</span> <span style=''>blood</span> <span style=''>cells</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>diagnostic</span> <span style=''>tool</span> <span style=''>in</span> <span style=''>medicine</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machines</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasingly</span> <span style=''>popular</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>and</span> <span style=''>could</span> <span style=''>replace</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>artificial</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>systems</span> <span style=''>Here</span> <span style=''>a</span> <span style=''>method</span> <span style=''>to</span> <span style=''>classify</span> <span style=''>blood</span> <span style=''>cells</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>using</span> <span style=''>SVM</span> <span style=''>A</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>on</span> <span style=''>images</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implemented</span> <span style=''>in</span> <span style=''>C</span> <span style=''>The</span> <span style=''>MPEG</span> <span style=''>7</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>descriptors</span> <span style=''>Scalable</span> <span style=''>Color</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Descriptor</span> <span style=''>Color</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structure</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Descriptor</span> <span style=''>Color</span> <span style=''>Layout</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Descriptor</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Homogeneous</span> <span style=''>Texture</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Descriptor</span> <span style=''>are</span> <span style=''>extended</span> <span style=''>in</span> <span style=''>size</span> <span style=''>and</span> <span style=''>combined</span> <span style=''>with</span> <span style=''>textural</span> <span style=''>features</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style=''>to</span> <span style=''>textural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perceived</span> <span style=''>visually</span> <span style=''>by</span> <span style=''>humans</span> <span style=''>From</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>images</span> <span style=''>of</span> <span style=''>human</span> <span style=''>blood</span> <span style=''>cells</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.11)
# 	architecture (0.09178571428571429)
# 	knowledge (0.13107142857142856)
# 	segmentation (0.07821428571428571)
# 	experimental (0.14464285714285716)
# 	detection (0.12928571428571428)
# 	convolutional (0.1225)
# 	recognition (0.13857142857142857)
# 	information (0.26571428571428574)
# 	different (0.27785714285714286)
#
# Some Statistics words are:
# 	algorithm (0.385)
# 	convergence (0.129)
# 	stochastic (0.1325)
# 	theoretical (0.1515)
# 	statistical (0.16)
# 	estimation (0.172)
# 	distribution (0.1835)
# 	dimensional (0.186)
# 	inference (0.194)
# 	regression (0.178)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bb0da422-4285-4dd1-9284-87019b0af9ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb0da422-4285-4dd1-9284-87019b0af9ce")) {                    Plotly.newPlot(                        "bb0da422-4285-4dd1-9284-87019b0af9ce",                        [{"x":["exponentially","prediction","significantly","ambiguity","connections","proposals","combinatorial","labelings","solutions","maximization","inference","tradeoffs","candidate","graphical","representations","constructions","appropriately","approximate","diversity","structured","augmentation","processing","potentials","algorithms","specifically","efficient","submodular","functions","constructed","synthetic","increasingly","experiments","available","dimensional","characterise","considerable","expensive","theoretical","experiment","baselines","strategies","optimisation","including","emphmulti","attention","validation","approximations","practical","applications","outperforms","performance","evaluations","properties","iterations","continuous","parameter","dictionary","supervision","representative","importance","collection","descriptors","generating","alleviate","important","classification","obtaining","opportunity","semantics","component","classificationretrieval","straightforward","dictionaries","conclusions","appearances","different","verifying","collections","descriptions","effective","distributed","difference","relationship","celebrities","restaurants","strengths","experimental","representation","outperform","represented","weaknesses","description","remarkable","simultaneously","algorithm","similarity","convergence","categories","alternating","supervised","furthermore","contributes","efficiently","retrieval","substantiate","impressive","introduced","structure","superiority","effectiveness","advantage","minimizing","structures","asymmetric","according","stochastic","asymptotic","optimality","cumulative","providing","numerical","accompanied","literature","asymptotically","comparison","bernoulli","positively","corresponding","acquiring","unrelated","separable","knowledge","marginally","variables","probabilistic","uncoupled","partitioned","respectively","disconnected","independent","relevance","containing","transitive","formulations","recognizing","convolution","extraction","comparing","currently","intricate","frequency","discriminative","recognition","architectures","convincing","additionally","addresses","extremely","posterior","partition","presented","particular","technique","demonstrate","unbalanced","dirichlet","parameters","clustering","automatically","objective","observations","increasing","expression","scenarios","conducted","environments","empirical","exploitative","discounting","distribution","extensive","optimistic","stationary","probability","systematically","approaches","integration","sentiment","framework","convolutional","embedding","embeddings","unlabeled","categorization","competing","resources","designing","reflecting","stabilizing","infrastructures","experience","organisation","perspective","typically","developments","standards","theoretically","scientific","interests","expertise","international","creativity","humanities","consortium","scientists","initiative","industrial","estimation","configurations","improvement","assumption","logarithmic","boltzmann","generalize","restricted","construct","justification","optimization","generative","empirically","regardless","euclidean","introduce","substantial","intervals","understanding","determine","evaluation","dangerous","trajectories","confidence","executing","autonomous","intractable","guarantees","estimated","desirable","transition","bootstrapping","conditions","parametric","orthogonal","exclusive","consistency", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	emphmulti
# 	selectors
# 	bernstein
# 	heteroscedastic
# 	homoscedastic
# 	backfitting
# 	surrogates
# 	logarithmically
# 	overtraining
# 	unsuccessful
# 	automates
# 	preconditioned
# 	blockwise
# 	integrality
# 	memberships
# 	complements
# 	blockmodel
# 	collinearity
# 	collaborators
# 	quantifiable
# Some words which never appear in Statistics papers:
# 	appearances
# 	celebrities
# 	restaurants
# 	creativity
# 	humanities
# 	dangerous
# 	executing
# 	paragraph
# 	upsampling
# 	occlusions
# 	latencies
# 	interconnections
# 	occupation
# 	interactivity
# 	conversational
# 	antecedent
# 	antecedents
# 	coreference
# 	colorization
# 	nonmonotonic

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.068896731624981e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7608333333333334
