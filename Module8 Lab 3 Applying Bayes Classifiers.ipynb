# %% [markdown]
# <a href="https://colab.research.google.com/github/rekhatanmayee29/FOUNDATION-OF-MODERM-MACHINE-LEARNING-23JN1A4556/blob/main/Module8%20Lab%203%20Applying%20Bayes%20Classifiers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-19 07:27:15--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   200MB/s    in 0.3s
#
# 2025-03-19 07:27:16 (200 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 17774  1802.09287v1  Spoken Language Translation (SLT) is becoming ...    cs
# 14250  1612.03301v2  We propose a novel coding theoretic framework ...  stat
# 29089  1708.03979v3  We introduce the Single Stage Headless (SSH) f...    cs
# 17381  1710.09233v1  Literary analysis, criticism or studies is a l...    cs
# 22459  1608.00441v1  Nonlinear similarity measures defined in kerne...  stat
# ...             ...                                                ...   ...
# 4832   1601.01297v2  We train a reinforcement learner to play a sim...    cs
# 8633   1708.05552v2  Convolutional neural networks have gained a re...    cs
# 12015  1706.02744v2  Recent work on fairness in machine learning ha...  stat
# 32848  1509.03200v1  Cluster analysis is one of the primary data an...    cs
# 36417   1401.2657v1  The population of elderly people keeps increas...    cs
#
#                                                    title  year  \
# 17774  Gender Aware Spoken Language Translation Appli...  2018
# 14250                                    Gradient Coding  2016
# 29089           SSH: Single Stage Headless Face Detector  2017
# 17381  A Simple Text Analytics Model To Assist Litera...  2017
# 22459  Kernel Risk-Sensitive Loss: Definition, Proper...  2016
# ...                                                  ...   ...
# 4832      Angrier Birds: Bayesian reinforcement learning  2016
# 8633   Practical Block-wise Neural Network Architectu...  2017
# 12015   Avoiding Discrimination through Causal Reasoning  2017
# 32848  A new Initial Centroid finding Method based on...  2015
# 36417  The Missing Ones: Key Ingredients Towards Effe...  2014
#
#                                                 keywords
# 17774  [translation, communication, challenges, trans...
# 14250  [theoretic, framework, mitigating, stragglers,...
# 29089  [introduce, classification, detectors, convolu...
# 17381  [criticism, dedicated, researchers, humanities...
# 22459  [nonlinear, similarity, correntropy, statistic...
# ...                                                  ...
# 4832   [reinforcement, simplified, algorithms, effici...
# 8633   [convolutional, remarkable, architectures, exp...
# 12015  [statistical, discrimination, observational, d...
# 32848  [technique, partitioning, clustering, algorith...
# 36417  [population, increasing, predominant, societie...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 17774    [translation, communication, challenges, trans...
# 14250    [theoretic, framework, mitigating, stragglers,...
# 29089    [introduce, classification, detectors, convolu...
# 17381    [criticism, dedicated, researchers, humanities...
# 22459    [nonlinear, similarity, correntropy, statistic...
#                                ...
# 34259    [recommender, providing, additional, informati...
# 14052    [optimization, significantly, influenced, homo...
# 13895    [generalization, recurrent, arbitrary, incorpo...
# 22982    [performing, inference, simulators, generally,...
# 6748     [collected, combination, conditions, recording...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8821 words.
# Out of those 4566 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8e62cf7e-808e-4dd3-bbf5-cb06d1d5f7a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e62cf7e-808e-4dd3-bbf5-cb06d1d5f7a1")) {                    Plotly.newPlot(                        "8e62cf7e-808e-4dd3-bbf5-cb06d1d5f7a1",                        [{"x":["improvement","limitation","challenges","information","significant","translation","agreement","communication","introduce","stragglers","distributed","replicating","tolerance","mitigating","gradients","generalization","approaches","synchronous","framework","theoretic","carefully","implement","detectors","simultaneously","parameters","additionally","classification","convolutional","different","available","invariant","improving","underlying","connected","surprisingly","properties","dedicated","criticism","component","analytics","techniques","reference","researchers","humanities","consistency","analyzing","performing","principal","validated","shakespeare","comparative","statistical","important","literature","confirmed","especially","theoretical","convergence","robustness","potentially","similarity","filtering","processing","algorithm","investigate","maintaining","definition","application","performance","statistics","counterparts","correntropy","sensitive","simulation","nonlinear","efficient","distribution","practical","frequentist","experiments","generalizing","financial","approximate","strategies","derivatives","inference","efficiency","stochastic","combination","differently","responses","corresponding","posterior","selection","generalized","numerical","estimators","particular","knowledge","demonstrate","probability","functional","randomized","reminiscent","dependent","motivated","illustrated","probabilistic","precisely","confidence","engineering","availability","approximated","traditional","formalise","empirically","expensive","synthetic","approximations","evaluations","behaviour","scientific","obtainable","eliminate","emphmulti","promising","applications","outperforms","optimisation","functions","likelihood","experimental","processes","distributions","criterion","regularized","witnessed","effectiveness","employing","regularizing","artifacts","automatically","typically","appearance","calculated","directional","coefficients","composite","construction","materials","automated","conditioning","estimation","deformation","deformations","variational","optimization","quantification","registration","introduces","throughout","calculate","parameterizable","regularization","hypothesis","forecaster","empirical","regarding","comparison","implementation","equivalent","minimizing","previously","estimator","scalability","establish","exponentially","classifiers","exploiting","contrastive","differential","divergence","intentions","cognitive","prediction","intention","multimodal","descriptors","experiment","performed","effective","acquisition","leveraging","involving","instantaneous","kinematics","quantitative","challenging","activities","demonstrating"],"y":[133,19,113,710,225,94,15,64,323,1,105,3,7,8,34,112,418,6,577,46,36,75,34,109,254,66,491,359,734,294,56,110,120,91,43,221,15,3,94,8,352,59,88,4,51,62,71,33,29,2,33,164,365,148,16,127,165,123,97,45,142,63,260,830,130,22,39,250,875,64,14,0,54,82,64,422,227,145,1,605,16,15,103,99,7,231,162,134,118,7,26,148,32,149,76,83,9,277,342,570,180,42,24,0,59,66,18,174,14,42,51,28,20,151,3,74,58,148,29,49,24,24,1,11,0,100,423,276,16,213,64,413,91,106,42,40,7,206,28,4,25,188,120,76,27,19,38,12,74,20,94,13,223,8,9,49,332,10,35,78,18,22,1,79,56,0,139,34,133,140,61,39,80,21,30,49,27,127,70,10,26,19,9,48,230,8,38,48,85,119,245,43,54,44,7,5,76,251,35,42],"type":"bar"},{"x":["improvement","limitation","challenges","information","significant","translation"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4566,), (4566, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8183333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style='background-color:rgba(0, 255, 0, 0.4000000000000001);'>Transductive</span> <span style=''>Semi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>Maximum</span> <span style=''>Margin</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <br/><br/><span style=''>Semi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>is</span> <span style=''>an</span> <span style=''>very</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>topic</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>The</span> <span style=''>key</span> <span style='background-color:rgba(0, 255, 0, 0.3025210084033614);'>challenge</span> <span style=''>of</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>how</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>a</span> <span style=''>metric</span> <span style=''>such</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.36619718309859156);'>instances</span> <span style=''>sharing</span> <span style=''>the</span> <span style=''>same</span> <span style=''>label</span> <span style=''>are</span> <span style=''>more</span> <span style=''>likely</span> <span style=''>close</span> <span style=''>to</span> <span style=''>each</span> <span style=''>other</span> <span style=''>on</span> <span style=''>the</span> <span style=''>embedded</span> <span style=''>space</span> <span style=''>However</span> <span style=''>little</span> <span style='background-color:rgba(0, 255, 0, 0.4672489082969432);'>attention</span> <span style=''>has</span> <span style=''>been</span> <span style=''>paid</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>better</span> <span style='background-color:rgba(0, 255, 0, 0.3454545454545454);'>representations</span> <span style=''>when</span> <span style=''>the</span> <span style=''>data</span> <span style=''>lie</span> <span style=''>on</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>manifold</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Fortunately</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>has</span> <span style=''>led</span> <span style=''>to</span> <span style=''>great</span> <span style=''>success</span> <span style=''>on</span> <span style=''>feature</span> <span style=''>learning</span> <span style=''>recently</span> <span style=''>Inspired</span> <span style=''>by</span> <span style=''>the</span> <span style=''>advances</span> <span style=''>of</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.4000000000000001);'>transductive</span> <span style=''>semi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>maximum</span> <span style=''>margin</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>approach</span> <span style=''>More</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specifically</span> <span style=''>given</span> <span style=''>pairwise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>we</span> <span style=''>exploit</span> <span style=''>both</span> <span style=''>labeled</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unlabeled</span> <span style=''>data</span> <span style=''>to</span> <span style=''>learn</span> <span style='' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Mutually</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dependent</span> <span style=''>Hadamard</span> <span style=''>Kernel</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Modelling</span> <span style=''>Latent</span> <span style=''>Variable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Couplings</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>kernel</span> <span style=''>that</span> <span style=''>models</span> <span style=''>input</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>couplings</span> <span style=''>across</span> <span style=''>multiple</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>The</span> <span style=''>pairwise</span> <span style=''>joint</span> <span style=''>kernel</span> <span style=''>measures</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>along</span> <span style=''>inputs</span> <span style=''>and</span> <span style=''>across</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>latent</span> <span style=''>signals</span> <span style=''>in</span> <span style=''>a</span> <span style=''>mutually</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependent</span> <span style=''>fashion</span> <span style=''>A</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlation</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>(LCGP)</span> <span style=''>model</span> <span style=''>combines</span> <span style=''>these</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationary</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>into</span> <span style=''>multiple</span> <span style=''>outputs</span> <span style=''>by</span> <span style=''>an</span> <span style=''>input</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependent</span> <span style=''>mixing</span> <span style=''>matrix</span> <span style=''>Probit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>and</span> <span style=''>support</span> <span style=''>for</span> <span style=''>multiple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observation</span> <span style=''>sets</span> <span style=''>are</span> <span style=''>derived</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>Results</span> <span style=''>on</span> <span style=''>several</span> <span style=''>datasets</span> <span style=''>indicate</span> <span style=''>that</span> <span style=''>the</span> <span style=''>LCGP</span> <span style=''>model</span> <span style=''>can</span> <span style=''>recover</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlations</span> <span style=''>between</span> <span style=''>latent</span> <span style=''>signals</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>achieving</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>highlight</span> <span style=''>the</span> <span style=''>latent</span> <span style='backgrou ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>From</span> <span style=''>An</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style='background-color:rgba(0, 255, 0, 0.6129032258064515);'>Viewpoint</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>dissertation</span> <span style=''>we</span> <span style=''>study</span> <span style='background-color:rgba(255, 0, 0, 0.3209109730848861);'>statistical</span> <span style=''>and</span> <span style=''>online</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>from</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>viewpointThe</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>dissertation</span> <span style=''>is</span> <span style=''>divided</span> <span style=''>into</span> <span style=''>two</span> <span style=''>parts</span> <span style=''>I</span> <span style=''>We</span> <span style=''>first</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>question</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>learnability</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3209109730848861);'>statistical</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>the</span> <span style=''>general</span> <span style=''>learning</span> <span style=''>setting</span> <span style=''>The</span> <span style=''>question</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>learnability</span> <span style=''>is</span> <span style=''>well</span> <span style=''>studied</span> <span style=''>and</span> <span style=''>fully</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterized</span> <span style=''>for</span> <span style=''>binary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>and</span> <span style=''>for</span> <span style=''>real</span> <span style=''>valued</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>using</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>of</span> <span style=''>uniform</span> <span style='background-color:rgba(255, 0, 0, 0.3422459893048129);'>convergence</span> <span style=''>However</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>for</span> <span style=''>the</span> <span style=''>general</span> <span style=''>learning</span> <span style=''>setting</span> <span style=''>uniform</span> <span style='background-color:rgba(255, 0, 0, 0.3422459893048129);'>convergence</span> <span style=''>theory</span> <span style=''>fails</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterize</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>learnability</span> <span style=''>To</span> <span style=''>fill</span> <span style=''>this</span> <span style=''>void</span> <span style=''>we</span> <span style=''>use</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stability</span> <span style=''>of</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>to</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterize</span> <span style='background-color:rgba(255, 0, 0, 0.3209109730848861);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>learnability</span> <span style=''>in</span> <span style=''>the</span> <span style=''>general</span> <span style=''>setting</span> <span style=''>Next</span> <span style=''>we</span> <span style=''>consider</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Security</span> <span style=''>Analysis</span> <span style=''>of</span> <span style=''>Online</span> <span style=''>Centroid</span> <span style=''>Anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Detection</span> <br/><br/><span style=''>Security</span> <span style=''>issues</span> <span style=''>are</span> <span style=''>crucial</span> <span style=''>in</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>especially</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scenarios</span> <span style=''>dealing</span> <span style=''>with</span> <span style=''>human</span> <span style=''>activity</span> <span style=''>rather</span> <span style=''>than</span> <span style=''>natural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>phenomena</span> <span style=''>(eg</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>ranking</span> <span style=''>spam</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>malware</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>etc)</span> <span style=''>It</span> <span style=''>is</span> <span style=''>to</span> <span style=''>be</span> <span style=''>expected</span> <span style=''>in</span> <span style=''>such</span> <span style=''>cases</span> <span style=''>that</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>will</span> <span style=''>have</span> <span style=''>to</span> <span style=''>deal</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>manipulated</span> <span style=''>data</span> <span style=''>aimed</span> <span style=''>at</span> <span style=''>hampering</span> <span style=''>decision</span> <span style=''>making</span> <span style=''>Although</span> <span style=''>some</span> <span style=''>previous</span> <span style=''>work</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>addressed</span> <span style=''>the</span> <span style=''>handling</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>malicious</span> <span style=''>data</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>very</span> <span style=''>little</span> <span style=''>is</span> <span style=''>known</span> <span style=''>about</span> <span style=''>the</span> <span style=''>behavior</span> <span style=''>of</span> <span style=''>anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>methods</span> <span style=''>in</span> <span style=''>such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scenarios</span> <span style=''>In</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contribution</span> <span style=''>we</span> <span style=''>analyze</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>method</span> <span style=''>online</span> <span style=''>centroid</span> <span style=''>anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>in</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>noise</span> <span style=''>Our</span> <span style=''>anal ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.1223613595706619)
# 	segmentation (0.0626118067978533)
# 	representation (0.1330948121645796)
# 	architecture (0.08980322003577818)
# 	experimental (0.14776386404293382)
# 	detection (0.11771019677996422)
# 	information (0.25402504472271914)
# 	different (0.2626118067978533)
# 	convolutional (0.12844364937388192)
# 	recognition (0.14311270125223613)
#
# Some Statistics words are:
# 	estimation (0.1685785536159601)
# 	stochastic (0.1371571072319202)
# 	distribution (0.17755610972568578)
# 	variables (0.14413965087281796)
# 	theoretical (0.15860349127182044)
# 	statistical (0.15910224438902743)
# 	algorithm (0.3980049875311721)
# 	inference (0.20448877805486285)
# 	dimensional (0.18753117206982545)
# 	regression (0.17805486284289276)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a27ba15c-a1ae-4c49-ab3a-72fd4f0a8034" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a27ba15c-a1ae-4c49-ab3a-72fd4f0a8034")) {                    Plotly.newPlot(                        "a27ba15c-a1ae-4c49-ab3a-72fd4f0a8034",                        [{"x":["improvement","limitation","challenges","information","significant","translation","agreement","communication","introduce","stragglers","distributed","replicating","tolerance","mitigating","gradients","generalization","approaches","synchronous","framework","theoretic","carefully","implement","detectors","simultaneously","parameters","additionally","classification","convolutional","different","available","invariant","improving","underlying","connected","surprisingly","properties","dedicated","criticism","component","analytics","techniques","reference","researchers","humanities","consistency","analyzing","performing","principal","validated","shakespeare","comparative","statistical","important","literature","confirmed","especially","theoretical","convergence","robustness","potentially","similarity","filtering","processing","algorithm","investigate","maintaining","definition","application","performance","statistics","counterparts","correntropy","sensitive","simulation","nonlinear","efficient","distribution","practical","frequentist","experiments","generalizing","financial","approximate","strategies","derivatives","inference","efficiency","stochastic","combination","differently","responses","corresponding","posterior","selection","generalized","numerical","estimators","particular","knowledge","demonstrate","probability","functional","randomized","reminiscent","dependent","motivated","illustrated","probabilistic","precisely","confidence","engineering","availability","approximated","traditional","formalise","empirically","expensive","synthetic","approximations","evaluations","behaviour","scientific","obtainable","eliminate","emphmulti","promising","applications","outperforms","optimisation","functions","likelihood","experimental","processes","distributions","criterion","regularized","witnessed","effectiveness","employing","regularizing","artifacts","automatically","typically","appearance","calculated","directional","coefficients","composite","construction","materials","automated","conditioning","estimation","deformation","deformations","variational","optimization","quantification","registration","introduces","throughout","calculate","parameterizable","regularization","hypothesis","forecaster","empirical","regarding","comparison","implementation","equivalent","minimizing","previously","estimator","scalability","establish","exponentially","classifiers","exploiting","contrastive","differential","divergence","intentions","cognitive","prediction","intention","multimodal","descriptors","experiment","performed","effective","acquisition","leveraging","involving","instantaneous","kinematics","quantitative","challenging","activities","demonstrating","overarching","capturing","contextual","affordable","technique","established","population","deterministic","preserved","correspondence","preprocessing","guaranteed","extracted","sufficient","extremely","correspondences","geometric","supplementary","significantly","computational","operations","reduction","increasing","generated","incorporating","relations","preference","accessible","importance","regularize","completion","augmented","reasoning","interpreter","programmers","incorporate","quantities","procedural","computation","differentiable","specified","integrate","objectives","behaviours","effectively","expressed","programming","structure","alternates","minimization","guarantees","celebrated","alternating","applicable","tractable","understa ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	correntropy
# 	reminiscent
# 	emphmulti
# 	forecaster
# 	degeneration
# 	lojasiewicz
# 	nesterovs
# 	collapsed
# 	uncollapsed
# 	thermodynamics
# 	proportionality
# 	advantageously
# 	statisticians
# 	practitioner
# 	stationarities
# 	chemoinformatics
# 	parameterizing
# 	ergodicity
# 	changepoint
# 	dendrogram
# Some words which never appear in Statistics papers:
# 	humanities
# 	shakespeare
# 	intentions
# 	kinematics
# 	interpreter
# 	programmers
# 	procedural
# 	pragmatics
# 	combinators
# 	repertoire
# 	categorial
# 	quantifiers
# 	recognizer
# 	necessitating
# 	ultrasound
# 	coreference
# 	oscillator
# 	oscillatory
# 	surpassing
# 	systematical

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0754090294009104e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7716666666666666
